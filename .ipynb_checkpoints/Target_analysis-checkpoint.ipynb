# %%
# Import Pandas, Numpy, Matplotlib, and Sqlite3
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
import sqlite3
from seaborn import plt
from matplotlib.dates import date2num, num2date

# This enables inline Plots
# %matplotlib inline

# %%
data_file = 'Medtrack_Deals-MA-Private_21Jan2015.csv'
#Add new column names, initial col names had spaces and slashes
df_cols = ['date', 'category', 'acquirer', 'target', 'value', 'headline']
df = pd.read_csv(data_file, sep=',', names = df_cols)
#Remove initial col names, anything w/o date or value
df = df[1:].dropna(subset=['date', 'value'])
#Replace commas in value and parse number
df['value'] = [float(v.replace(',','')) for v in df.value]
#Check only for values > 100M
df = df[df.value >= 500]
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#         date              category  \
# 0  1/16/2015  Majority Acquisition
# 1  1/13/2015                  Exit
# 2  1/12/2015  Majority Acquisition
# 3  1/11/2015  Majority Acquisition
# 4   1/1/2015  Majority Acquisition
#
#                                         acquirer  \
# 0                            Roche Holding, Ltd.
# 1                Otsuka Pharmaceutical Co., Ltd.
# 2                            Roche Holding, Ltd.
# 3                              Biogen Idec, Inc.
# 4  Elanco India Pvt., Ltd.|Eli Lilly and Company
#
#                               target   value  \
# 0                         Trophos SA   550.7
# 1       AVANIR Pharmaceuticals, Inc.  1495.2
# 2          Foundation Medicine, Inc.   780.0
# 3  Convergence Pharmaceuticals, Ltd.   675.0
# 4       Novartis Animal Health, Inc.  5400.0
#
#                                             headline
# 0                           Roche to acquire Trophos
# 1  Baker Brother, T. Rowe Price, and Fidelity Man...
# 2  Roche Holding to acquire majority stake in Fou...
# 3  Biogen Idec to acquire Convergence Pharmaceuti...
# 4  Eli Lilly and Company acquires Novartis Animal...

# %%
dname = df.target[1]

# %%
import re
import json
import urllib

s_name = urllib.quote(dname)
url = 'http://d.yimg.com/autoc.finance.yahoo.com/autoc?query={name}&callback=YAHOO.Finance.SymbolSuggest.ssCallback'.format(name = s_name)
string = urllib.urlopen(url).read()
string = string.replace('YAHOO.Finance.SymbolSuggest.ssCallback(','')
string = string[:-1]
string
# Out:
# '{"ResultSet":{"Query":"avanir pharmaceuticals, inc.","Result":[{"symbol":"AVNR","name":"Avanir Pharmaceuticals, Inc.","exch":"NMS","type":"S","exchDisp":"NASDAQ","typeDisp":"Equity"}]}}'

# %%
data = json.loads(string)
result = data['ResultSet']['Result']
if len(result) == 0:
    symbol = ''
else:
    symbol = result[0]['symbol']
symbol
# Out:
# u'AVNR'

# %%
#function to search yahoo for symbol based on comp name, parse to json, then pull first symbol entry
def name_to_symbol(cname):
    s_name = urllib.quote(cname)
    url = 'http://d.yimg.com/autoc.finance.yahoo.com/autoc?query={name}&callback=YAHOO.Finance.SymbolSuggest.ssCallback'.format(name = s_name)
    string = urllib.urlopen(url).read()
    string = string.replace('YAHOO.Finance.SymbolSuggest.ssCallback(','')
    string = string[:-1]
    data = json.loads(string)
    result = data['ResultSet']['Result']
    if len(result) == 0:
        symbol = ''
    else:
        symbol = result[0]['symbol']
    return symbol

# %%
name_to_symbol('Pfasdf')
# Out:
# nan

# %%
symbol = []
for name in df.target:
    symbol.append(name_to_symbol(name))
symbol
# Out:
# ['',
#  u'AVNR',
#  u'FMI',
#  '',
#  '',
#  '',
#  u'NBHGY',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'CFN',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'QCOR',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'FURX',
#  '',
#  '',
#  '',
#  '',
#  u'ARTC',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'ALGZF.PK',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'LYB',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'CRTSF',
#  u'CRTSF',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'CRTSF',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'HHCSY',
#  '',
#  '',
#  u'CFN',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'INCR',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'BAYRY',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'BAYRY',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'HITK',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'DRTX',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'ACCL',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'CBM',
#  '',
#  '',
#  '',
#  u'OPTR',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'MDXX.PK',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'VOLC',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'MAKO',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'AUXL',
#  u'SNTS',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'AVNR',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'VRSK',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'NPSP',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'ITMN',
#  u'WCRX',
#  '',
#  '',
#  '',
#  '',
#  u'CBST',
#  '',
#  '',
#  '',
#  u'ONXX',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'SIAL',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  u'ESPR',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
df['t_symbol'] = symbol
df.head()
# Out:
#         date              category  \
# 0  1/16/2015  Majority Acquisition
# 1  1/13/2015                  Exit
# 2  1/12/2015  Majority Acquisition
# 3  1/11/2015  Majority Acquisition
# 4   1/1/2015  Majority Acquisition
#
#                                         acquirer  \
# 0                            Roche Holding, Ltd.
# 1                Otsuka Pharmaceutical Co., Ltd.
# 2                            Roche Holding, Ltd.
# 3                              Biogen Idec, Inc.
# 4  Elanco India Pvt., Ltd.|Eli Lilly and Company
#
#                               target   value  \
# 0                         Trophos SA   550.7
# 1       AVANIR Pharmaceuticals, Inc.  1495.2
# 2          Foundation Medicine, Inc.   780.0
# 3  Convergence Pharmaceuticals, Ltd.   675.0
# 4       Novartis Animal Health, Inc.  5400.0
#
#                                             headline t_symbol
# 0                           Roche to acquire Trophos
# 1  Baker Brother, T. Rowe Price, and Fidelity Man...     AVNR
# 2  Roche Holding to acquire majority stake in Fou...      FMI
# 3  Biogen Idec to acquire Convergence Pharmaceuti...
# 4  Eli Lilly and Company acquires Novartis Animal...

# %%
def get_historical_prices(symbol, date):
    """
    Get historical prices for the given ticker symbol.
    First will need to split date on '/'
    
    Returns a json list.
    """
    m2, d2, y2 = date.split('/')
    m2 = str(int(m2) - 1)
    d1 = d2
    m1 = m2
    y1 = str(int(y2) - 1)
    
    url = 'http://ichart.yahoo.com/table.csv?s=%s&' % symbol + \
          'd=%s&' % m2 + \
          'e=%s&' % d2 + \
          'f=%s&' % y2 + \
          'g=d&' + \
          'a=%s&' % m1 + \
          'b=%s&' % d1 + \
          'c=%s&' % y1 + \
          'ignore=.csv'
    days = urllib.urlopen(url).readlines()
#     return days
    data = [day[:-2].split(',') for day in days]
    return data

# %%
data = get_historical_prices('PFE', '1/1/2015')
#Take second and last rows, second column is open cost
new = float(data[1][1])
old = float(data[-1][1])
new, old
# Out:
# (31.18, 30.47)

# %%
start = []
end = []
for i in range(len(df)):
    if df.t_symbol[i] == '':
        start.append('')
        end.append('')
    else:
        data = get_historical_prices(df.t_symbol[i], df.date[i])
        if len(data[0]) == 1:
            start.append('')
            end.append('')
        else:
            start.append(float(data[-1][1]))
            end.append(float(data[1][1]))
# Out:
# True

# %%
df['t_start'] = start
df['t_end'] = end
df.head()
# Out:
#         date              category  \
# 0  1/16/2015  Majority Acquisition
# 1  1/13/2015                  Exit
# 2  1/12/2015  Majority Acquisition
# 3  1/11/2015  Majority Acquisition
# 4   1/1/2015  Majority Acquisition
#
#                                         acquirer  \
# 0                            Roche Holding, Ltd.
# 1                Otsuka Pharmaceutical Co., Ltd.
# 2                            Roche Holding, Ltd.
# 3                              Biogen Idec, Inc.
# 4  Elanco India Pvt., Ltd.|Eli Lilly and Company
#
#                               target   value  \
# 0                         Trophos SA   550.7
# 1       AVANIR Pharmaceuticals, Inc.  1495.2
# 2          Foundation Medicine, Inc.   780.0
# 3  Convergence Pharmaceuticals, Ltd.   675.0
# 4       Novartis Animal Health, Inc.  5400.0
#
#                                             headline t_symbol t_start  t_end
# 0                           Roche to acquire Trophos
# 1  Baker Brother, T. Rowe Price, and Fidelity Man...     AVNR    3.32  16.96
# 2  Roche Holding to acquire majority stake in Fou...      FMI   24.28  54.19
# 3  Biogen Idec to acquire Convergence Pharmaceuti...
# 4  Eli Lilly and Company acquires Novartis Animal...

# %%
#Count number of entries
len(df[df.t_start != ''])
# Out:
# 27

# %%
dif = []
for i in range(len(df)):
    if df.t_start[i] == '':
        dif.append('')
    else:
       dif.append(df.t_end[i] - df.t_start[i])
df['t_dif'] = dif
df.head()
# Out:
#         date              category  \
# 0  1/16/2015  Majority Acquisition
# 1  1/13/2015                  Exit
# 2  1/12/2015  Majority Acquisition
# 3  1/11/2015  Majority Acquisition
# 4   1/1/2015  Majority Acquisition
#
#                                         acquirer  \
# 0                            Roche Holding, Ltd.
# 1                Otsuka Pharmaceutical Co., Ltd.
# 2                            Roche Holding, Ltd.
# 3                              Biogen Idec, Inc.
# 4  Elanco India Pvt., Ltd.|Eli Lilly and Company
#
#                               target   value  \
# 0                         Trophos SA   550.7
# 1       AVANIR Pharmaceuticals, Inc.  1495.2
# 2          Foundation Medicine, Inc.   780.0
# 3  Convergence Pharmaceuticals, Ltd.   675.0
# 4       Novartis Animal Health, Inc.  5400.0
#
#                                             headline t_symbol t_start  t_end  \
# 0                           Roche to acquire Trophos
# 1  Baker Brother, T. Rowe Price, and Fidelity Man...     AVNR    3.32  16.96
# 2  Roche Holding to acquire majority stake in Fou...      FMI   24.28  54.19
# 3  Biogen Idec to acquire Convergence Pharmaceuti...
# 4  Eli Lilly and Company acquires Novartis Animal...
#
#    t_dif
# 0
# 1  13.64
# 2  29.91
# 3
# 4
